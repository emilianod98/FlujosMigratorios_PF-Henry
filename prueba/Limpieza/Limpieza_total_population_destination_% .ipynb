# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
by_sex_destination  = pd.read_excel("Datasets/undesa_pd_2020_ims_stock_by_sex_and_destination.xlsx", sheet_name="Table 3", skiprows=10)

# %%
by_sex_destination
# Out:
#      Unnamed: 0 Region, development group, country or area  Notes  \
# 0             1                                      WORLD    NaN
# 1             2                         Sub-Saharan Africa    NaN
# 2             3           Northern Africa and Western Asia    NaN
# 3             4                  Central and Southern Asia    NaN
# 4             5             Eastern and South-Eastern Asia    NaN
# ..          ...                                        ...    ...
# 278         279                                      Samoa    NaN
# 279         280                                   Tokelau*   40.0
# 280         281                                      Tonga    NaN
# 281         282                                     Tuvalu    NaN
# 282         283                 Wallis and Futuna Islands*   41.0
#
#      Location code Type of data       1990       1995       2000       2005  \
# 0              900          NaN   2.871776   2.807869   2.819741   2.926468
# ...

# %%
columnas_años = by_sex_destination.columns[5:12]
diccionario_mapeo = {col: f'Both {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data Both 1990 Both 1995 Both 2000 Both 2005  \
# 0            900          NaN  2.871776  2.807869  2.819741  2.926468
# 1            947          NaN  2.708155  2.545733  2.055967  1.958301
# 2           1833          NaN  6.112873  5.851901  5.710156  5.909862
# 3            921          NaN    2.1104  1.543949  1.332074   1.14473
# 4           1832          NaN   0.37196  0.427634  0.513804  0.610684
#
#   Both 2010  ...    2010.1     2015.1     2020.1    1990.2    1995.2  \
# 0  3.176495  ...  3.248304   3.446614    3.70628   2.85008  2.794757
# ...

# %%
columnas_años = by_sex_destination.columns[12:19]
diccionario_mapeo = {col: f'Male {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data Both 1990 Both 1995 Both 2000 Both 2005  \
# 0            900          NaN  2.871776  2.807869  2.819741  2.926468
# 1            947          NaN  2.708155  2.545733  2.055967  1.958301
# 2           1833          NaN  6.112873  5.851901  5.710156  5.909862
# 3            921          NaN    2.1104  1.543949  1.332074   1.14473
# 4           1832          NaN   0.37196  0.427634  0.513804  0.610684
#
#   Both 2010  ... Male 2010.1 Male 2015.1 Male 2020.1    1990.2    1995.2  \
# 0  3.176495  ...    3.248304    3.446614     3.70628   2.85008  2.794757
# ...

# %%
columnas_años = by_sex_destination.columns[19:30]
diccionario_mapeo = {col: f'Female {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data Both 1990 Both 1995 Both 2000 Both 2005  \
# 0            900          NaN  2.871776  2.807869  2.819741  2.926468
# 1            947          NaN  2.708155  2.545733  2.055967  1.958301
# 2           1833          NaN  6.112873  5.851901  5.710156  5.909862
# 3            921          NaN    2.1104  1.543949  1.332074   1.14473
# 4           1832          NaN   0.37196  0.427634  0.513804  0.610684
#
#   Both 2010  ... Male 2010.1 Male 2015.1 Male 2020.1 Female 1990.2  \
# 0  3.176495  ...    3.248304    3.446614     3.70628       2.85008
# ...

# %%
columnas_modificar = by_sex_destination.columns[12:]
by_sex_destination.rename(columns=lambda x: x[:-2] if x in columnas_modificar else x, inplace=True)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data Both 1990 Both 1995 Both 2000 Both 2005  \
# 0            900          NaN  2.871776  2.807869  2.819741  2.926468
# 1            947          NaN  2.708155  2.545733  2.055967  1.958301
# 2           1833          NaN  6.112873  5.851901  5.710156  5.909862
# 3            921          NaN    2.1104  1.543949  1.332074   1.14473
# 4           1832          NaN   0.37196  0.427634  0.513804  0.610684
#
#   Both 2010  ... Male 2010  Male 2015  Male 2020 Female 1990 Female 1995  \
# 0  3.176495  ...  3.248304   3.446614    3.70628     2.85008    2.794757
# ...

# %%
by_sex_destination.replace("..", 0, inplace=True)

# %%
by_sex_destination = by_sex_destination.drop(["Unnamed: 0", "Notes", "Location code", "Type of data"], axis=1)

by_sex_destination.head()
# Out:
#   Region, development group, country or area  Both 1990  Both 1995  Both 2000  \
# 0                                      WORLD   2.871776   2.807869   2.819741
# 1                         Sub-Saharan Africa   2.708155   2.545733   2.055967
# 2           Northern Africa and Western Asia   6.112873   5.851901   5.710156
# 3                  Central and Southern Asia   2.110400   1.543949   1.332074
# 4             Eastern and South-Eastern Asia   0.371960   0.427634   0.513804
#
#    Both 2005  Both 2010  Both 2015  Both 2020  Male 1990  Male 1995  ...  \
# 0   2.926468   3.176495   3.359966   3.599812   2.893193   2.820799  ...
# 1   1.958301   1.895663   2.161732   2.030541   2.888092   2.695156  ...
# 2   5.909862   7.496767   8.729874   9.463901   6.959506   6.751883  ...
# 3   1.144730   1.108326   1.015978   0.964287   2.069456   1.495914  ...
# 4   0.610684   0.715797   0.790870   0.834833   0.375940   0.423474  ...
#
# ...

# %%
fila_migraciones = by_sex_destination.iloc[0]

# Obtener los valores de las migraciones
valores_migraciones = fila_migraciones.values[1:8]

# Crear el gráfico de barras
columnas_migraciones = by_sex_destination.columns[1:8]
plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Both)')
plt.xticks(rotation=90)

plt.show()

# %%
fila_migraciones = by_sex_destination.iloc[0]

valores_migraciones = fila_migraciones.values[8:15]
columnas_migraciones = by_sex_destination.columns[8:15]

plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Male)')
plt.xticks(rotation=90)

plt.show()

# %%
fila_migraciones = by_sex_destination.iloc[0]

valores_migraciones = fila_migraciones.values[15:22]
columnas_migraciones = by_sex_destination.columns[15:22]

plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Female)')
plt.xticks(rotation=90)

plt.show()

# %%
by_sex_destination.to_csv('Datasets_Limpios/total_population_destination_%.csv', index=False)
