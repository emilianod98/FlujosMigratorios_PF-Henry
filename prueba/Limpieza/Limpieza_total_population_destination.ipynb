# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
by_sex_destination  = pd.read_excel("Datasets/undesa_pd_2020_ims_stock_by_sex_and_destination.xlsx", sheet_name="Table 2", skiprows=10)

# %%
by_sex_destination
# Out:
#      Unnamed: 0 Region, development group, country or area  Notes  \
# 0             1                                      WORLD    NaN
# 1             2                         Sub-Saharan Africa    NaN
# 2             3           Northern Africa and Western Asia    NaN
# 3             4                  Central and Southern Asia    NaN
# 4             5             Eastern and South-Eastern Asia    NaN
# ..          ...                                        ...    ...
# 278         279                                      Samoa    NaN
# 279         280                                   Tokelau*   40.0
# 280         281                                      Tonga    NaN
# 281         282                                     Tuvalu    NaN
# 282         283                 Wallis and Futuna Islands*   41.0
#
#      Location code Type of data         1990         1995         2000  \
# 0              900          NaN  5327231.041  5744212.930  6143493.806
# 1              947          NaN   490604.852   560759.472   639661.386
# 2             1833          NaN   288060.443   323178.117   355881.668
# 3              921          NaN  1239984.308  1376199.571  1511915.310
# 4             1832          NaN  1837799.004  1950219.950  2044789.220
# ..             ...          ...          ...          ...          ...
# 278            882          B R      162.797      170.050      174.454
# 279            772          B R        1.604        1.507        1.550
# 280            776          B R       95.069       95.972       97.962
# 281            798            C        8.910        9.298        9.392
# 282            876          B R       13.794       14.147       14.697
#
#             2005         2010  ...       2010.1       2015.1       2020.1  \
# 0    6541906.956  6956823.588  ...  3507703.635  3720696.374  3929973.953
# 1     729733.003   836363.757  ...   416385.807   477837.402   546155.739
# 2     391985.543   435366.790  ...   222726.512   246800.019   270179.461
# 3    1647073.789  1775360.533  ...   916462.273   977497.118  1037597.732
# 4    2125348.402  2201806.674  ...  1117990.393  1156649.075  1189407.443
# ..           ...          ...  ...          ...          ...          ...
# 278      179.722      185.944  ...       95.979      100.037      102.703
# 279        1.213        1.129  ...           ..           ..           ..
# 280      100.908      103.981  ...        52.13       50.373       52.904
# 281        9.997       10.521  ...           ..           ..           ..
# 282       14.937       12.686  ...           ..           ..           ..
#
#           1990.2       1995.2       2000.2       2005.2       2010.2  \
# 0    2646335.779  2852071.381  3050059.948  3245421.689  3449119.953
# 1     246553.851   281959.578   321660.406   366787.492    419977.95
# 2     142401.577   159554.008   175940.112   192852.125   212640.278
# 3     599452.744   664718.267   730388.632   795643.537    858898.26
# 4     904695.513   960578.235  1007731.985  1046985.743  1083816.281
# ..           ...          ...          ...          ...          ...
# 278       77.816       81.607       83.572       86.593       89.965
# 279           ..           ..           ..           ..           ..
# 280        46.84       47.288         48.1       50.256       51.851
# 281           ..           ..           ..           ..           ..
# 282           ..           ..           ..           ..           ..
#
#           2015.2       2020.2
# 0    3659100.593  3864824.776
# 1     480739.799   548209.866
# 2     234719.996   255689.821
# 3     918830.175   977110.799
# 4    1122840.541  1157302.038
# ..           ...          ...
# 278       93.473       95.707
# 279           ..           ..
# 280       50.407       52.793
# 281           ..           ..
# 282           ..           ..
#
# [283 rows x 26 columns]

# %%
columnas_años = by_sex_destination.columns[5:12]
diccionario_mapeo = {col: f'Both {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data    Both 1990    Both 1995    Both 2000  \
# 0            900          NaN  5327231.041  5744212.930  6143493.806
# 1            947          NaN   490604.852   560759.472   639661.386
# 2           1833          NaN   288060.443   323178.117   355881.668
# 3            921          NaN  1239984.308  1376199.571  1511915.310
# 4           1832          NaN  1837799.004  1950219.950  2044789.220
#
#      Both 2005    Both 2010  ...       2010.1       2015.1       2020.1  \
# 0  6541906.956  6956823.588  ...  3507703.635  3720696.374  3929973.953
# 1   729733.003   836363.757  ...   416385.807   477837.402   546155.739
# 2   391985.543   435366.790  ...   222726.512   246800.019   270179.461
# 3  1647073.789  1775360.533  ...   916462.273   977497.118  1037597.732
# 4  2125348.402  2201806.674  ...  1117990.393  1156649.075  1189407.443
#
#         1990.2       1995.2       2000.2       2005.2       2010.2  \
# 0  2646335.779  2852071.381  3050059.948  3245421.689  3449119.953
# 1   246553.851   281959.578   321660.406   366787.492    419977.95
# 2   142401.577   159554.008   175940.112   192852.125   212640.278
# 3   599452.744   664718.267   730388.632   795643.537    858898.26
# 4   904695.513   960578.235  1007731.985  1046985.743  1083816.281
#
#         2015.2       2020.2
# 0  3659100.593  3864824.776
# 1   480739.799   548209.866
# 2   234719.996   255689.821
# 3   918830.175   977110.799
# 4  1122840.541  1157302.038
#
# [5 rows x 26 columns]

# %%
columnas_años = by_sex_destination.columns[12:19]
diccionario_mapeo = {col: f'Male {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data    Both 1990    Both 1995    Both 2000  \
# 0            900          NaN  5327231.041  5744212.930  6143493.806
# 1            947          NaN   490604.852   560759.472   639661.386
# 2           1833          NaN   288060.443   323178.117   355881.668
# 3            921          NaN  1239984.308  1376199.571  1511915.310
# 4           1832          NaN  1837799.004  1950219.950  2044789.220
#
#      Both 2005    Both 2010  ...  Male 2010.1  Male 2015.1  Male 2020.1  \
# 0  6541906.956  6956823.588  ...  3507703.635  3720696.374  3929973.953
# 1   729733.003   836363.757  ...   416385.807   477837.402   546155.739
# 2   391985.543   435366.790  ...   222726.512   246800.019   270179.461
# 3  1647073.789  1775360.533  ...   916462.273   977497.118  1037597.732
# 4  2125348.402  2201806.674  ...  1117990.393  1156649.075  1189407.443
#
#         1990.2       1995.2       2000.2       2005.2       2010.2  \
# 0  2646335.779  2852071.381  3050059.948  3245421.689  3449119.953
# 1   246553.851   281959.578   321660.406   366787.492    419977.95
# 2   142401.577   159554.008   175940.112   192852.125   212640.278
# 3   599452.744   664718.267   730388.632   795643.537    858898.26
# 4   904695.513   960578.235  1007731.985  1046985.743  1083816.281
#
#         2015.2       2020.2
# 0  3659100.593  3864824.776
# 1   480739.799   548209.866
# 2   234719.996   255689.821
# 3   918830.175   977110.799
# 4  1122840.541  1157302.038
#
# [5 rows x 26 columns]

# %%
columnas_años = by_sex_destination.columns[19:30]
diccionario_mapeo = {col: f'Female {col}' for col in columnas_años}
by_sex_destination = by_sex_destination.rename(columns=diccionario_mapeo)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data    Both 1990    Both 1995    Both 2000  \
# 0            900          NaN  5327231.041  5744212.930  6143493.806
# 1            947          NaN   490604.852   560759.472   639661.386
# 2           1833          NaN   288060.443   323178.117   355881.668
# 3            921          NaN  1239984.308  1376199.571  1511915.310
# 4           1832          NaN  1837799.004  1950219.950  2044789.220
#
#      Both 2005    Both 2010  ...  Male 2010.1  Male 2015.1  Male 2020.1  \
# 0  6541906.956  6956823.588  ...  3507703.635  3720696.374  3929973.953
# 1   729733.003   836363.757  ...   416385.807   477837.402   546155.739
# 2   391985.543   435366.790  ...   222726.512   246800.019   270179.461
# 3  1647073.789  1775360.533  ...   916462.273   977497.118  1037597.732
# 4  2125348.402  2201806.674  ...  1117990.393  1156649.075  1189407.443
#
#   Female 1990.2 Female 1995.2 Female 2000.2 Female 2005.2 Female 2010.2  \
# 0   2646335.779   2852071.381   3050059.948   3245421.689   3449119.953
# 1    246553.851    281959.578    321660.406    366787.492     419977.95
# 2    142401.577    159554.008    175940.112    192852.125    212640.278
# 3    599452.744    664718.267    730388.632    795643.537     858898.26
# 4    904695.513    960578.235   1007731.985   1046985.743   1083816.281
#
#   Female 2015.2 Female 2020.2
# 0   3659100.593   3864824.776
# 1    480739.799    548209.866
# 2    234719.996    255689.821
# 3    918830.175    977110.799
# 4   1122840.541   1157302.038
#
# [5 rows x 26 columns]

# %%
columnas_modificar = by_sex_destination.columns[12:]
by_sex_destination.rename(columns=lambda x: x[:-2] if x in columnas_modificar else x, inplace=True)

by_sex_destination.head(5)
# Out:
#    Unnamed: 0 Region, development group, country or area  Notes  \
# 0           1                                      WORLD    NaN
# 1           2                         Sub-Saharan Africa    NaN
# 2           3           Northern Africa and Western Asia    NaN
# 3           4                  Central and Southern Asia    NaN
# 4           5             Eastern and South-Eastern Asia    NaN
#
#    Location code Type of data    Both 1990    Both 1995    Both 2000  \
# 0            900          NaN  5327231.041  5744212.930  6143493.806
# 1            947          NaN   490604.852   560759.472   639661.386
# 2           1833          NaN   288060.443   323178.117   355881.668
# 3            921          NaN  1239984.308  1376199.571  1511915.310
# 4           1832          NaN  1837799.004  1950219.950  2044789.220
#
#      Both 2005    Both 2010  ...    Male 2010    Male 2015    Male 2020  \
# 0  6541906.956  6956823.588  ...  3507703.635  3720696.374  3929973.953
# 1   729733.003   836363.757  ...   416385.807   477837.402   546155.739
# 2   391985.543   435366.790  ...   222726.512   246800.019   270179.461
# 3  1647073.789  1775360.533  ...   916462.273   977497.118  1037597.732
# 4  2125348.402  2201806.674  ...  1117990.393  1156649.075  1189407.443
#
#    Female 1990  Female 1995  Female 2000  Female 2005  Female 2010  \
# 0  2646335.779  2852071.381  3050059.948  3245421.689  3449119.953
# 1   246553.851   281959.578   321660.406   366787.492    419977.95
# 2   142401.577   159554.008   175940.112   192852.125   212640.278
# 3   599452.744   664718.267   730388.632   795643.537    858898.26
# 4   904695.513   960578.235  1007731.985  1046985.743  1083816.281
#
#    Female 2015  Female 2020
# 0  3659100.593  3864824.776
# 1   480739.799   548209.866
# 2   234719.996   255689.821
# 3   918830.175   977110.799
# 4  1122840.541  1157302.038
#
# [5 rows x 26 columns]

# %%
by_sex_destination.replace("..", 0, inplace=True)

# %%
by_sex_destination = by_sex_destination.drop(["Unnamed: 0", "Notes", "Location code", "Type of data"], axis=1)

by_sex_destination.head()
# Out:
#   Region, development group, country or area    Both 1990    Both 1995  \
# 0                                      WORLD  5327231.041  5744212.930
# 1                         Sub-Saharan Africa   490604.852   560759.472
# 2           Northern Africa and Western Asia   288060.443   323178.117
# 3                  Central and Southern Asia  1239984.308  1376199.571
# 4             Eastern and South-Eastern Asia  1837799.004  1950219.950
#
#      Both 2000    Both 2005    Both 2010    Both 2015    Both 2020  \
# 0  6143493.806  6541906.956  6956823.588  7379796.967  7794798.729
# 1   639661.386   729733.003   836363.757   958577.201  1094365.605
# 2   355881.668   391985.543   435366.790   481520.015   525869.282
# 3  1511915.310  1647073.789  1775360.533  1896327.293  2014708.531
# 4  2044789.220  2125348.402  2201806.674  2279489.616  2346709.481
#
#      Male 1990    Male 1995  ...    Male 2010    Male 2015    Male 2020  \
# 0  2680895.262  2892141.549  ...  3507703.635  3720696.374  3929973.953
# 1   244051.001   278799.894  ...   416385.807   477837.402   546155.739
# 2   145658.866   163624.109  ...   222726.512   246800.019   270179.461
# 3   640531.564   711481.304  ...   916462.273   977497.118  1037597.732
# 4   933103.491   989641.715  ...  1117990.393  1156649.075  1189407.443
#
#    Female 1990  Female 1995  Female 2000  Female 2005  Female 2010  \
# 0  2646335.779  2852071.381  3050059.948  3245421.689  3449119.953
# 1   246553.851   281959.578   321660.406   366787.492   419977.950
# 2   142401.577   159554.008   175940.112   192852.125   212640.278
# 3   599452.744   664718.267   730388.632   795643.537   858898.260
# 4   904695.513   960578.235  1007731.985  1046985.743  1083816.281
#
#    Female 2015  Female 2020
# 0  3659100.593  3864824.776
# 1   480739.799   548209.866
# 2   234719.996   255689.821
# 3   918830.175   977110.799
# 4  1122840.541  1157302.038
#
# [5 rows x 22 columns]

# %%
fila_migraciones = by_sex_destination.iloc[0]

# Obtener los valores de las migraciones
valores_migraciones = fila_migraciones.values[1:8]

# Crear el gráfico de barras
columnas_migraciones = by_sex_destination.columns[1:8]
plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Both)')
plt.xticks(rotation=90)

plt.show()

# %%
fila_migraciones = by_sex_destination.iloc[0]

valores_migraciones = fila_migraciones.values[8:15]
columnas_migraciones = by_sex_destination.columns[8:15]

plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Male)')
plt.xticks(rotation=90)

plt.show()

# %%
fila_migraciones = by_sex_destination.iloc[0]

valores_migraciones = fila_migraciones.values[15:22]
columnas_migraciones = by_sex_destination.columns[15:22]

plt.bar(columnas_migraciones, valores_migraciones)
plt.xlabel('Year')
plt.ylabel('Migration Stock')
plt.title('Migration Total Population per Year(Female)')
plt.xticks(rotation=90)

plt.show()

# %%
by_sex_destination.to_csv('Datasets_Limpios/total_population_destination.csv', index=False)
